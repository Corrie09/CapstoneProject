# %%
import pandas as pd

# Load the dataset (notebook is in EDA/, data is in project_root/data/)
descriptive_stats = pd.read_csv("descriptive_stats_by_market.csv")

descriptive_stats.head()
# Out:
#   market_seriousness_category  effort_index_mean  effort_index_std  \
# 0                     low_ltr              0.670             0.212
# 1                  medium_ltr              0.687             0.191
# 2                    high_ltr              0.689             0.186
#
#    rating_index_mean  rating_index_std  age_mean  education_level_mean  \
# 0              0.601             0.148    29.610                 3.399
# 1              0.629             0.124    31.757                 3.243
# 2              0.586             0.124    33.228                 3.283
#
#    is_ltr_oriented_mean  market_id_count
# 0                 0.345              765
# 1                 0.506            34298
# 2                 0.609            24883

# %%
import pandas as pd

# Load the dataset (notebook is in EDA/, data is in project_root/data/)
market_indices = pd.read_csv("market_indices.csv")

market_indices.head()
# Out:
#                                    market_id  \
# 0  south_san_francisco_california_m_straight
# 1              oakland_california_m_straight
# 2        san_francisco_california_m_straight
# 3             berkeley_california_m_straight
# 4        san_francisco_california_f_straight
#
#                                target_market  target_ltr_share  \
# 0  south_san_francisco_california_f_straight            0.5444
# 1              oakland_california_f_straight            0.5014
# 2        san_francisco_california_f_straight            0.5012
# 3             berkeley_california_f_straight            0.5005
# 4        san_francisco_california_m_straight            0.5821
#
#    target_avg_effort  target_avg_rating  target_market_size  \
# 0             0.6274             0.5671                 270
# 1             0.7053             0.6248                3217
# 2             0.6786             0.6518               15712
# 3             0.7096             0.6629                2116
# ...

# %%
import pandas as pd

# Load the dataset (notebook is in EDA/, data is in project_root/data/)
market_level_summary_stats = pd.read_csv("market_level_summary_stats.csv")

market_level_summary_stats.head()
# Out:
#   Unnamed: 0  target_ltr_share  target_avg_effort  target_avg_rating  \
# 0      count           465.000            465.000            465.000
# 1       mean             0.547              0.697              0.573
# 2        std             0.331              0.134              0.092
# 3        min             0.000              0.102              0.257
# 4        25%             0.400              0.647              0.522
#
#    target_avg_completeness  target_avg_age  target_avg_education  \
# 0                  465.000         465.000               437.000
# 1                    0.824          32.403                 3.087
# 2                    0.080           7.446                 0.618
# 3                    0.316          18.000                 1.000
# 4                    0.790          27.667                 2.882
#
#    target_market_size
# 0             465.000
# 1             128.916
# 2             917.756
# 3               1.000
# 4               1.000

# %%
import pandas as pd

# Load the dataset (notebook is in EDA/, data is in project_root/data/)
okcupid_final_analysis_ready = pd.read_csv("okcupid_final_analysis_ready.csv")

okcupid_final_analysis_ready.head()
# Out:
#    age     status sex orientation       body_type               diet  \
# 0   22     single   m    straight  a little extra  strictly anything
# 1   35     single   m    straight         average       mostly other
# 2   38  available   m    straight            thin           anything
# 3   23     single   m    straight            thin         vegetarian
# 4   29     single   m    straight        athletic                NaN
#
#      drinks      drugs                          education  \
# 0  socially      never      working on college/university
# 1     often  sometimes              working on space camp
# 2  socially        NaN     graduated from masters program
# 3  socially        NaN      working on college/university
# 4  socially      never  graduated from college/university
#
#              ethnicity  ...  target_avg_rating  target_avg_completeness  \
# 0         asian, white  ...             0.5671                   0.8238
# ...
